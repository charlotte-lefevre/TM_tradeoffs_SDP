# %% [markdown]
# # Nouveaux graphiques avec le nouvel algorithe "MemBlowUp"
#
# ## 1 : Déterminer de nouveau quelles sont les dissections intéressantes

# %%
import sys
import matplotlib.pyplot as plt
sys.path.insert(1, '../Functions_utils/')


import numpy as np
import math
import matplotlib.pyplot as plt


import GetTimeMemoryTradeOffs

load("../Functions_utils/WaveParams.py")

# %% [markdown]
# ## Montrer que cela ne sert pas vraiment a grand chose d'aller au dela d'une 30 dissection et en deca d'une 7

# %%
plt.figure(figsize = (15,10))
axes = plt.gca()
axes.set_ylim([0.01*math.log(3,2),0.04])
axes.set_xlim([0.0*math.log(3,2),0.0120*math.log(3,2)])

Dissections_two  = range(7,30)
h = 2

Remin = 0.01
Remax = 0.07

for X in Dissections_two:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "black")
        


Dissections_two_not_interesting  = np.append(range(2,7), range(30,40,2))
for X in Dissections_two_not_interesting:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "red")
# Out:
# ../Functions_utils/GetTimeMemoryTradeOffs.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   Lambda = math.log(3,2)*Re/denominateur - (R+Re)/(denominateur*X**(h-1))

# %% [markdown]
# Ensuite, on passe les h=2 dissections en argent,
# on regarde les h=3 et on montre la meme chose (en fait on essaye de se convaincre qu'on loupe aucun trade off strictement meilleur)

# %%
plt.figure(figsize = (15,10))
axes = plt.gca()
axes.set_ylim([0.01*math.log(3,2),0.04])
axes.set_xlim([0.0*math.log(3,2),0.0120*math.log(3,2)])

Dissections_two  = range(7,30)
h = 2

Remin = 0.01
Remax = 0.07

for X in Dissections_two:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "silver", s=10)
        
Dissections_three  = range(4,12)
h = 3


for X in Dissections_three:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "black")
        


Dissections_three_not_interesting  = np.append([2,3], range(12,30))

for X in Dissections_three_not_interesting:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "red", s = 2)

# %% [markdown]
# Et idem pour la h=4 dissection

# %%
plt.figure(figsize = (15,10))
axes = plt.gca()
axes.set_ylim([0.01*math.log(3,2),0.04])
axes.set_xlim([0.0*math.log(3,2),0.0120*math.log(3,2)])

Dissections_two  = range(7,30)
h = 2

Remin = 0.01
Remax = 0.07

for X in Dissections_two:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "silver", s=10)
        
Dissections_three  = range(4,12)
h = 3


for X in Dissections_three:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "silver", s = 10)
        


Dissections_four = [4]
h = 4

for X in Dissections_four:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "black", s = 10)
        

Dissections_four_not_interesting  = np.append([2,3], range(5,10))

for X in Dissections_four_not_interesting:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "red", s = 2)

# %% [markdown]
# Et 5, 6 etages ?

# %%
plt.figure(figsize = (15,10))
axes = plt.gca()
axes.set_ylim([0.01*math.log(3,2),0.04])
axes.set_xlim([0.0*math.log(3,2),0.0120*math.log(3,2)])

Dissections_two  = range(7,30)
h = 2

Remin = 0.01
Remax = 0.07

for X in Dissections_two:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "silver", s=10)
        
Dissections_three  = range(4,12)
h = 3


for X in Dissections_three:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "silver", s = 10)
        


Dissections_four = [4]
h = 4

for X in Dissections_four:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "black", s = 10)
        

Dissections  = range(2,10)
h = 5
Remin = 0.001
for X in Dissections:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "red", s = 2)
        
h = 6
for X in Dissections:
        (memories, times,_, _) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax)
        plt.scatter(memories, times, c = "red", s = 2)

# %% [markdown]
# Finalement on se retrouve avec

# %%
Dissections_two  = range(7,30)
Dissections_three  = range(4,12)
Dissections_four = [4]

# %%
import dissection_best_complexity
M_dissec,T_dissec,Res_dissection = dissection_best_complexity.compute_best_complexity_dissection(R, W,200)

# %%
load("../Functions_utils/plot_dissections.py")


Plot_dissection(GetTimeMemoryTradeOffs.Apply)

#plt.plot([m * math.log(3,2) for m in M_dissec],[t * math.log(3,2) for t in T_dissec],c = "black", marker = ".", linewidth=0, markersize = 3, label = "one dissection")

plt.legend()

plt.savefig("FullTradeoff.jpg")

# %% [markdown]
# Avec moins de points : pour etre plus clairs

# %%
import matplotlib.pyplot as plt
from matplotlib import cm 
from matplotlib.colors import ListedColormap,LinearSegmentedColormap
import numpy as np
import math
import sys
sys.path.insert(1, '.')

from Wagner import Wagner_base2
from Wagner import Wagner_lisse_base2

R = 0.676
w =0.948366
W = w
Remin = 0.01
Remax = 0.2
npoints = 400

plt.figure(figsize=(18,9))

# Customized cmap, each cmap is for one level of dissection
Blues_modified = cm.get_cmap('Blues', 256)# create new hsv colormaps in range of 0.3 (green) to 0.7 (blue)
Oranges_modified = cm.get_cmap('Oranges', 256)# create new hsv colormaps in range of 0.3 (green) to 0.7 (blue)
cmap2 = ListedColormap(Blues_modified(np.linspace(0.9, 0.3, 256)))
cmap3 = ListedColormap(Oranges_modified(np.linspace(0.9, 0.3, 256)))

# Set x,y limits
axes = plt.gca()
axes.set_ylim([0.01*math.log(3,2),0.04])
axes.set_xlim([0.0*math.log(3,2),0.0120*math.log(3,2)])


## Plotting level 2 dissections
h = 2
Interesting_dissections_two = [7,11,16,22,29]
M = []
T = []
track_colormap = [] 
for X in Interesting_dissections_two:
    (memories, times,_, Res) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax, nbRes=npoints)
    track_colormap = np.append(track_colormap, [X for _ in range(0, len(memories))])
    M = np.append(M, memories)
    T = np.append(T, times)

plt.scatter(M, T, s = 3, c = track_colormap, cmap = cmap2)
cbar = plt.colorbar()
cbar.set_label('Dissection 2 levels')
## Plotting level 3 dissections
h = 3
Interesting_dissections_three = [4,7,11]
colors = ["darkred", "orange", "bisque"]; icols = 0
for X in Interesting_dissections_three:
    (memories, times,_, Res) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax, nbRes=npoints)
    plt.scatter(memories, times, s=3, c=colors[icols], label = "X = " +str(X) + " h = " +str(h))
    icols = icols + 1


h = 4
X = 4
(memories, times,_, Res) = GetTimeMemoryTradeOffs.Apply(X, h, R,W, Remin=Remin, Remax=Remax, nbRes=npoints)
plt.scatter(memories, times, s = 3, c="forestgreen", label="4-4 dissection")



#dissection + Wave TM
plt.plot(2/11*0.060835*math.log(3,2),2/11*0.060835*math.log(3,2),"silver", label="Wave",marker=".", linewidth = 0, markersize = 8)

# Wave TM tardeoff plotting
memories = np.linspace(0.001*math.log(3,2), 2/11*0.060835*math.log(3,2), 100)
TM_tradeoff = [-m + 4/11*0.060835*math.log(3,2) for m in memories]
plt.plot(memories, TM_tradeoff, "red", label="Wave TM tardeoff")




mems,complexities, Reused,_  = Wagner_lisse_base2(R, W,npoints=200,Remax = 0.08)
plt.plot(mems,complexities, markersize = 6, linewidth = 0, color = "orange", marker = 'x', label = "Wagner lissé")

mems,complexities, Reused,_  = Wagner_base2(R, W,npoints=200,Remax = 0.08)
plt.plot(mems,complexities, markersize = 6, linewidth = 0, color = "green", marker = 'x', label = "Wagner ")


TMM = [2*m for m in memories]
TMMM = [3*m for m in memories]
TMMMM = [4*m for m in memories]

plt.plot(memories, TMM, "slateblue", label="T=M**2", linewidth=0.3)
plt.plot(memories, TMMM, "darkorchid", label="T=M**3", linewidth=0.3)
plt.plot(memories, TMMMM, "violet", label="T=M**4", linewidth=0.3)

plt.legend()
plt.title("Different complexitites - log2")

plt.savefig("SimplifiedTradeoff.jpg")
